# %% [markdown]
# # Setup

# %%
# Import needed libraries

from google.colab import drive  # to mount Google Drive to Colab notebook
import tweepy                   # Python wrapper around Twitter API
import json
import pandas as pd
import csv
from datetime import date
from datetime import datetime
import time
import matplotlib.pyplot as plt

# %%
# Mounting Google Drive

drive.mount('/content/gdrive')
path = './gdrive/My Drive/datasets/twitter_analysis/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # Twitter Data Collection

# %% [markdown]
# ## Log into Twitter API

# %%
# Load Twitter API secrets from an external file
secrets = json.loads(open(path + 'secrets.json').read())  

consumer_key = secrets['consumer_key']
consumer_secret = secrets['consumer_secret']
access_token = secrets['access_token']
access_token_secret = secrets['access_token_secret']

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Save JSON file

# %%
# Helper function to save data into a JSON file
# file_name: the name of the data file you want to save on your Google Drive
# file_content: the data you want to save

def save_json(file_name, file_content):
  with open(path + file_name, 'w', encoding='utf-8') as f:
    json.dump(file_content, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Twitter API limit handling

# %%
# Helper function to handle twitter API rate limit

def limit_handled(cursor, list_name):
    while True:
        try:
            yield cursor.next()
        except tweepy.RateLimitError:
            print("\nCurrent number of data points in list = " + str(len(list_name)))
            print('Hit Twitter API rate limit.')
            for i in range(3, 0, -1):
              print("Wait for {} mins.".format(i * 5))
              time.sleep(5 * 60)
        except tweepy.error.TweepError:
            print('\nCaught TweepError exception' )

# %%
# update these for whatever tweet you want to process replies to
name = 'malkassabi'
tweet_id = '1212081182365622273'

replies=[]
cursor = tweepy.Cursor(api.search,q='to:'+name, result_type='recent', timeout=999999).items(1000)
for tweet in cursor:
    if hasattr(tweet, 'in_reply_to_status_id_str'):
        if (tweet.in_reply_to_status_id_str==tweet_id):
            replies.append(tweet)

# save_json('replies.json', replies)

with open(path + 'replies.csv', 'wb') as f:
    csv_writer = csv.DictWriter(f, fieldnames=('user', 'text'))
    csv_writer.writeheader()
    for tweet in replies:
        row = {'user': tweet.user.screen_name, 'text': tweet.text.encode('ascii', 'ignore').replace('\n', ' ')}
        csv_writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-12-7c47e6db5b09> in <module>()
#       4 replies=[]
#       5 cursor = tweepy.Cursor(api.search,q='to:'+name, result_type='recent', timeout=999999).items(1000)
# ----> 6 for tweet in cursor:
#       7     if hasattr(tweet, 'in_reply_to_status_id_str'):
#       8         if (tweet.in_reply_to_status_id_str==tweet_id):
#
# /usr/local/lib/python3.6/dist-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# /usr/local/lib/python3.6/dist-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /usr/local/lib/python3.6/dist-packages/tweepy/cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# /usr/local/lib/python3.6/dist-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# /usr/local/lib/python3.6/dist-packages/tweepy/binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %%
len(replies)
# Out:
# 349

# %% [markdown]
# ## Data Collection Functions

# %% [markdown]
# ### Get all tweets

# %%
# Helper function to get all tweets for a specified user
# NOTE:  This method only allows access to the most recent 3240 tweets
# Source: https://gist.github.com/yanofsky/5436496

def get_all_tweets(screen_name):

	# initialize a list to hold all the tweepy Tweets
	alltweets = []	
	
	# make initial request for most recent tweets (200 is the maximum allowed count)
	new_tweets = api.user_timeline(screen_name = screen_name,count=200)
	
	# save most recent tweets
	alltweets.extend(new_tweets)
	
	# save the id of the oldest tweet less one
	oldest = alltweets[-1].id - 1
	
	# keep grabbing tweets until there are no tweets left to grab
	while len(new_tweets) > 0:
		print("getting tweets before %s" % (oldest))
		
		# all subsiquent requests use the max_id param to prevent duplicates
		new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
		
		# save most recent tweets
		alltweets.extend(new_tweets)
		
		# update the id of the oldest tweet less one
		oldest = alltweets[-1].id - 1
		
		print("...%s tweets downloaded so far" % (len(alltweets)))
	
	# transform the tweepy tweets into a 2D array that will populate the csv	
	outtweets = [[tweet.id_str, tweet.created_at, tweet.text, tweet.favorite_count, 
	              tweet.in_reply_to_screen_name, tweet.retweeted] for tweet in alltweets]
	
	# write the csv	
	with open(path + '%s_tweets.csv' % screen_name, 'w') as f:
		writer = csv.writer(f)
		writer.writerow(["id","created_at","text","likes","in reply to","retweeted"])
		writer.writerows(outtweets)
	
	pass

# %% [markdown]
# ### Get today's twitter stats

# %%
# Helper function to get today's numbers of followers and friends and store 
# them into a JSON file

def todays_stats(dict_name):
  info = api.me()
  followers_cnt = info.followers_count
  following_cnt = info.friends_count
  today = date.today()
  d = today.strftime("%b %d, %Y")
  if d not in dict_name:
    dict_name[d] = {"followers":followers_cnt, "following":following_cnt}
    save_json("follower_history.json", dict_name)
  else:
    print('Today\'s stats already exist')

# %% [markdown]
# ### Get followers data

# %%
# Helper function to load follower objects into a list and save it into 
# a JSON file. 

def get_followers():
  followers = []

  cursor = tweepy.Cursor(api.followers, count=200).pages()
  for i, page in enumerate(limit_handled(cursor, followers)):
      print("\r"+"Loading"+ i % 5 *".", end='')
      followers += page

  followers = [x._json for x in followers]
  save_json('followers_data.json', followers)

# %% [markdown]
# ### Get friends data

# %%
# Load friends into list

def get_friends():
  friends = []

  for i, page in enumerate(limit_handled(tweepy.Cursor(api.friends, count=200).pages(), friends)):
      print("\r"+"Loading"+ i % 5 *".", end='')
      friends += page

  friends = [x._json for x in friends]
  save_json('friends_data.json', friends)

# %% [markdown]
# ## Data Collection Main Script

# %%
if __name__ == '__main__':
  #pass in the username of the account you want to download
  get_all_tweets("yakhoja")
  with open(path + 'follower_history.json') as json_file:
    history = json.load(json_file)
  todays_stats(history)
  get_followers()
  get_friends()
# Out:
# Loading....
# Current number of data points in list = 3000
# Hit Twitter API rate limit.
# Wait for 15 mins.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-7-f77e9b688570> in limit_handled(cursor, list_name)
#       4         try:
# ----> 5             yield cursor.next()
#       6         except tweepy.RateLimitError:
#
# /usr/local/lib/python3.6/dist-packages/tweepy/cursor.py in next(self)
#      74                                     *self.args,
# ---> 75                                     **self.kargs)
#      76         self.prev_cursor, self.next_cursor = cursors
#
# /usr/local/lib/python3.6/dist-packages/tweepy/binder.py in _call(*args, **kwargs)
#     249         else:
# --> 250             return method.execute()
#     251
#
# /usr/local/lib/python3.6/dist-packages/tweepy/binder.py in execute(self)
#     231                 if is_rate_limit_error_message(error_msg):
# --> 232                     raise RateLimitError(error_msg, resp)
#     233                 else:
#
# RateLimitError: [{'message': 'Rate limit exceeded', 'code': 88}]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-7f71c104f9c5> in <module>()
#       5   #   history = json.load(json_file)
#       6   # todays_stats(history)
# ----> 7   get_followers()
#       8   # get_friends()
#
# <ipython-input-8-914544678a2c> in get_followers()
#       4
#       5   cursor = tweepy.Cursor(api.followers, count=200).pages()
# ----> 6   for i, page in enumerate(limit_handled(cursor, followers)):
#       7       print("\r"+"Loading"+ i % 5 *".", end='')
#       8       followers += page
#
# <ipython-input-7-f77e9b688570> in limit_handled(cursor, list_name)
#       9             for i in range(3, 0, -1):
#      10               print("Wait for {} mins.".format(i * 5))
# ---> 11               time.sleep(5 * 60)
#      12         except tweepy.error.TweepError:
#      13             print('\nCaught TweepError exception' )
#
# KeyboardInterrupt:

# %%
api.followers()
# Out:
# [User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 1144553539458539520, 'id_str': '1144553539458539520', 'name': 'Hanafi Pasha', 'screen_name': 'HanafiPasha', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 0, 'friends_count': 1885, 'listed_count': 0, 'created_at': 'Fri Jun 28 10:30:03 +0000 2019', 'favourites_count': 7938, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'can_media_tag': False, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1144553539458539520, id_str='1144553539458539520', name='Hanafi Pasha', screen_name='HanafiPasha', location='', description='', url=None, entities={'description': {'urls': []}}, protected=True, followers_count=0, friends_count=1885, listed_count=0, created_at=datetime.datetime(2019, 6, 28, 10, 30, 3), favourites_count=7938, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=0, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=True, default_profile_image=True, can_media_tag=False, followed_by=True, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none'),
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 2475008994, 'id_str': '2475008994', 'name': 'يارب', 'screen_name': 'llii2112', 'location': '', 'description': '.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 126, 'friends_count': 2299, 'listed_count': 0, 'created_at': 'Sat May 03 05:53:38 +0000 2014', 'favourites_count': 7352, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 684, 'lang': None, 'status': {'created_at': 'Wed Dec 11 12:16:47 +0000 2019', 'id': 1204736787454857217, 'id_str': '1204736787454857217', 'text': 'RT @339001: @DesMeet صباح الخير، أحتاج مختص في تصميم المواقع وصفحات الويب للعمل بمشروع شخصي.. دُلوني 🌿', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': '339001', 'name': 'مَنار', 'id': 234923996, 'id_str': '234923996', 'indices': [3, 10]}, {'screen_name': 'DesMeet', 'name': 'ملتقى المصممين', 'id': 305404599, 'id_str': '305404599', 'indices': [12, 20]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Dec 10 21:49:03 +0000 2019', 'id': 1204518415504990213, 'id_str': '1204518415504990213', 'text': '@DesMeet صباح الخير، أحتاج مختص في تصميم المواقع وصفحات الويب للعمل بمشروع شخصي.. دُلوني 🌿', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'DesMeet', 'name': 'ملتقى المصممين', 'id': 305404599, 'id_str': '305404599', 'indices': [0, 8]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 305404599, 'in_reply_to_user_id_str': '305404599', 'in_reply_to_screen_name': 'DesMeet', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 13, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1192394477169762306/otk-x8vy_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1192394477169762306/otk-x8vy_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2475008994/1399096775', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=2475008994, id_str='2475008994', name='يارب', screen_name='llii2112', location='', description='.', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=126, friends_count=2299, listed_count=0, created_at=datetime.datetime(2014, 5, 3, 5, 53, 38), favourites_count=7352, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=684, lang=None, status=Status(_api=<tweepy.api.API object at 0x7 ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 1204644728869916674, 'id_str': '1204644728869916674', 'name': 'مهدي الحبابي', 'screen_name': 'RM21hqn0dREkYeS', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 18, 'listed_count': 0, 'created_at': 'Wed Dec 11 06:12:29 +0000 2019', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1204644728869916674, id_str='1204644728869916674', name='مهدي الحبابي', screen_name='RM21hqn0dREkYeS', location='', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=0, friends_count=18, listed_count=0, created_at=datetime.datetime(2019, 12, 11, 6, 12, 29), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=0, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=True, default_profile_image=True, can_media_tag=True, followed_by=True, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none'),
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 231083846, 'id_str': '231083846', 'name': 'Dr. Muhanna Al-Muhanna', 'screen_name': 'dtmmuhanna', 'location': 'KACST/ NANOTECHNOLOGY ', 'description': 'Associate Ressearch Prof of Pharmaceutics & BioNanotechnology at the National Nanotechnology Center/', 'url': 'https://t.co/QodvnsgLxZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/QodvnsgLxZ', 'expanded_url': 'https://www.researchgate.net/profile/Muhanna_Al-Muhanna', 'display_url': 'researchgate.net/profile/Muhann…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 149, 'friends_count': 1733, 'listed_count': 0, 'created_at': 'Mon Dec 27 15:08:54 +0000 2010', 'favourites_count': 284, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 559, 'lang': None, 'status': {'created_at': 'Thu Dec 12 19:57:14 +0000 2019', 'id': 1205215049901576193, 'id_str': '1205215049901576193', 'text': 'RT @saudinewsdaily: #اميره_العباس_غيرسعوديه\nهذه هي تقدم صورة مشوهة عن وضع الفتاة السعودية\nهذه السورية الشعية ناشطة فيما يسمى  بـ(إسقاط الول…', 'truncated': False, 'entities': {'hashtags': [{'text': 'اميره_العباس_غيرسعوديه', 'indices': [20, 43]}], 'symbols': [], 'user_mentions': [{'screen_name': 'saudinewsdaily', 'name': 'الدكتورة حنان بنت فهد القاسمي', 'id': 3790381092, 'id_str': '3790381092', 'indices': [3, 18]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Dec 12 08:17:52 +0000 2019', 'id': 1205039048613605377, 'id_str': '1205039048613605377', 'text': '#اميره_العباس_غيرسعوديه\nهذه هي تقدم صورة مشوهة عن وضع الفتاة السعودية\nهذه السورية الشعية ناشطة فيما يسمى  بـ(إسقاط… https://t.co/OiqXsvCVY4', 'truncated': True, 'entities': {'hashtags': [{'text': 'اميره_العباس_غيرسعوديه', 'indices': [0, 23]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/OiqXsvCVY4', 'expanded_url': 'https://twitter.com/i/web/status/1205039048613605377', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 40, 'favorite_count': 47, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'ar'}, 'is_quote_status': False, 'retweet_count': 40, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3260721616/64efef0078ee3e89dc55dddc419315fe_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3260721616/64efef0078ee3e89dc55dddc419315fe_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/231083846/1538851786', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_reque ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 59426191, 'id_str': '59426191', 'name': 'هــاجر', 'screen_name': 'hager42', 'location': 'في مكان ما', 'description': '#تسقط_بس ...', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 549, 'friends_count': 506, 'listed_count': 1, 'created_at': 'Thu Jul 23 10:58:25 +0000 2009', 'favourites_count': 4501, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5332, 'lang': None, 'status': {'created_at': 'Wed Dec 11 17:07:10 +0000 2019', 'id': 1204809865954234369, 'id_str': '1204809865954234369', 'text': '@shambat2000 اكل الحرام ما كويس 😂😂😂', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'shambat2000', 'name': 'Mai Albashir', 'id': 223736215, 'id_str': '223736215', 'indices': [0, 12]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1204794688689049600, 'in_reply_to_status_id_str': '1204794688689049600', 'in_reply_to_user_id': 223736215, 'in_reply_to_user_id_str': '223736215', 'in_reply_to_screen_name': 'shambat2000', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '9AE4E8', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1741834060/Voyager__By_Michael_Oswald_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1741834060/Voyager__By_Michael_Oswald_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/59426191/1371836114', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDFFCC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'can_media_tag': False, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=59426191, id_str='59426191', name='هــاجر', screen_name='hager42', location='في مكان ما', description='#تسقط_بس ...', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=549, friends_count=506, listed_count=1, created_at=datetime.datetime(2009, 7, 23, 10, 58, 25), favourites_count=4501, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=5332, lang=None, status=Status(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'created_at': 'Wed Dec 11 17:07:10 +0000 2019', 'id': 1204809865954234369, 'id_str': '1204809865954234369', 'text': '@shambat2000 اكل الحرام ما كويس 😂😂😂', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'shambat2000', 'name': 'Mai Albashir', 'id': 223736215, 'id_str': '223736215', 'indices': [0, 12]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1204794688689049600, 'in_reply_to_status_id_str': '1204794688689049600', 'in_reply_to_user_id': 223736215, 'in_reply_to_user_id_str': '223736215', 'in_reply_to_screen_name': 'shambat2000', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, created_at=datetime.datetime(2019, 12, 11, 17, 7, 10), id=1204809865954234 ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 2539006707, 'id_str': '2539006707', 'name': 'احمدمحمدقسم الله', 'screen_name': 'ahmedgesm162', 'location': 'النيل الأبيض كوستي', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 18, 'friends_count': 210, 'listed_count': 0, 'created_at': 'Sat May 10 12:57:55 +0000 2014', 'favourites_count': 15, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 84, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/933694464824152065/sw6mQ9Mz_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/933694464824152065/sw6mQ9Mz_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=2539006707, id_str='2539006707', name='احمدمحمدقسم الله', screen_name='ahmedgesm162', location='النيل الأبيض كوستي', description='', url=None, entities={'description': {'urls': []}}, protected=True, followers_count=18, friends_count=210, listed_count=0, created_at=datetime.datetime(2014, 5, 10, 12, 57, 55), favourites_count=15, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=84, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/933694464824152065/sw6mQ9Mz_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/933694464824152065/sw6mQ9Mz_normal.jpg', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=True, default_profile_image=False, can_media_tag=True, followed_by=True, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none'),
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 1205068992462897152, 'id_str': '1205068992462897152', 'name': 'محمد إبراهيم', 'screen_name': 'g7mShZ2cef4ZlMf', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 28, 'listed_count': 0, 'created_at': 'Thu Dec 12 10:17:02 +0000 2019', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1205068992462897152, id_str='1205068992462897152', name='محمد إبراهيم', screen_name='g7mShZ2cef4ZlMf', location='', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=0, friends_count=28, listed_count=0, created_at=datetime.datetime(2019, 12, 12, 10, 17, 2), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=0, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=True, default_profile_image=True, can_media_tag=True, followed_by=True, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none'),
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 764202865, 'id_str': '764202865', 'name': 'الشاعر عبدالله احمد الشاطري', 'screen_name': 'abdulla9shatri', 'location': 'جدة, المملكة العربية السعودية', 'description': '\u200f\u200f\u200f\u200f\u200f\u200fأشهد أن لا إلـﮧ إلاَّ اللـَّـﮧ \r\nو أشهد أن مُـכـمَّــدْ رَسُــولُ اللـَّـﮧ\r\n\n**********\r\n\nقناتي على اليوتيوب\r\n\n\nhttps://t.co/p5zEf4rpDr\u200e\u200e', 'url': 'https://t.co/RcBYKf4a3o', 'entities': {'url': {'urls': [{'url': 'https://t.co/RcBYKf4a3o', 'expanded_url': 'https://m.facebook.com/a.alshatrie?ref=bookmarks', 'display_url': 'm.facebook.com/a.alshatrie?re…', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/p5zEf4rpDr', 'expanded_url': 'http://m.youtube.com/user/alshatrie1', 'display_url': 'm.youtube.com/user/alshatrie1', 'indices': [118, 141]}]}}, 'protected': False, 'followers_count': 136, 'friends_count': 212, 'listed_count': 0, 'created_at': 'Fri Aug 17 18:21:40 +0000 2012', 'favourites_count': 141, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 116, 'lang': None, 'status': {'created_at': 'Fri Nov 15 03:08:46 +0000 2019', 'id': 1195176787703222273, 'id_str': '1195176787703222273', 'text': 'RT @ekhbariya_eco: فيديو | منتدى التقنيات الناشئة يناقش المستجدات والتقنيات والتطبيقات #الإخبارية #أموال_ومسارات https://t.co/W70DdHeodV', 'truncated': False, 'entities': {'hashtags': [{'text': 'الإخبارية', 'indices': [87, 97]}, {'text': 'أموال_ومسارات', 'indices': [98, 112]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ekhbariya_eco', 'name': 'الإخبارية - اقتصاد', 'id': 829746884147298307, 'id_str': '829746884147298307', 'indices': [3, 17]}], 'urls': [], 'media': [{'id': 1194176689884090368, 'id_str': '1194176689884090368', 'indices': [113, 136], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1194176689884090368/pu/img/CKvZlRmyMMaswznR.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1194176689884090368/pu/img/CKvZlRmyMMaswznR.jpg', 'url': 'https://t.co/W70DdHeodV', 'display_url': 'pic.twitter.com/W70DdHeodV', 'expanded_url': 'https://twitter.com/ekhbariya_eco/status/1194176772092448769/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 640, 'h': 360, 'resize': 'fit'}, 'medium': {'w': 640, 'h': 360, 'resize': 'fit'}, 'small': {'w': 640, 'h': 360, 'resize': 'fit'}}, 'source_status_id': 1194176772092448769, 'source_status_id_str': '1194176772092448769', 'source_user_id': 829746884147298307, 'source_user_id_str': '829746884147298307', 'features': {}}]}, 'extended_entities': {'media': [{'id': 1194176689884090368, 'id_str': '1194176689884090368', 'indices': [113, 136], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1194176689884090368/pu/img/CKvZlRmyMMaswznR.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1194176689884090368/pu/img/CKvZlRmyMMaswznR.jpg', 'url': 'https://t.co/W70DdHeodV', 'display_url': 'pic.twitter.com/W70DdHeodV', 'expanded_url': 'https://twitter.com/ekhbariya_eco/status/1194176772092448769/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 640, 'h': 360, 'resize': 'fit'}, 'medium': {'w': 640, 'h': 360, 'resize': 'fit'}, 'small': {'w': 640, 'h': 360, 'resize': 'fit'}}, 'source_status_id': 1194176772092448769, 'source_status_id_str': '1194176772092448769', 'source_user_id': 829746884147298307, 'source_user_id_str': '829746884147298307', 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 132720, 'variants': [{'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1194176689884090368/pu/vid/640x360/fLpFew20ontXkEd9.mp4?tag=10'}, {'bitrate': 256000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1194176689884090368/pu/vid/480x270/anOeR3E6SzwPiDsw.mp4?tag=10'}, {'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/1194 ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 566859017, 'id_str': '566859017', 'name': '#فارررسس', 'screen_name': 'makman121', 'location': 'KSA, Riyadh .. ', 'description': '✨ Nothing good comes easy ⚡️', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 288, 'friends_count': 301, 'listed_count': 0, 'created_at': 'Mon Apr 30 02:58:25 +0000 2012', 'favourites_count': 384, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3953, 'lang': None, 'status': {'created_at': 'Thu Dec 12 17:03:31 +0000 2019', 'id': 1205171331710492672, 'id_str': '1205171331710492672', 'text': 'RT @yakhoja: اهم المكتبات المستخدمة\n- مكتبة tweepy لاستخدام واجهة برمجية (API) لتويتر بلغة بايثون\n- مكتبة pandas لمعالجة البيانات في جداول…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'yakhoja', 'name': 'Yehia Khoja | يحيى خوجه', 'id': 2163821632, 'id_str': '2163821632', 'indices': [3, 11]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Dec 09 17:51:33 +0000 2019', 'id': 1204096256345292800, 'id_str': '1204096256345292800', 'text': 'اهم المكتبات المستخدمة\n- مكتبة tweepy لاستخدام واجهة برمجية (API) لتويتر بلغة بايثون\n- مكتبة pandas لمعالجة البيانا… https://t.co/OiZh2XR1BV', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/OiZh2XR1BV', 'expanded_url': 'https://twitter.com/i/web/status/1204096256345292800', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1204096241979809792, 'in_reply_to_status_id_str': '1204096241979809792', 'in_reply_to_user_id': 2163821632, 'in_reply_to_user_id_str': '2163821632', 'in_reply_to_screen_name': 'yakhoja', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 4, 'favorite_count': 24, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'ar'}, 'is_quote_status': False, 'retweet_count': 4, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'EDECE9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1192266638604865537/bK4VwMx8_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1192266638604865537/bK4VwMx8_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/566859017/1439924656', 'profile_link_color': '088253', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=566859017, id_str='566859017', name='#فارررسس', screen_name='makman121', location='KSA, Riyadh .. ', description='✨ Nothing good comes easy ⚡️', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=288, friends_count=301, listed_count=0, created_at=da ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 1167476384522002432, 'id_str': '1167476384522002432', 'name': 'badriya', 'screen_name': 'badriyanas', 'location': '', 'description': 'عمل عمل عمل شغل عمل عمل موسيقى عمل فن عمل عمل عمل', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 13, 'friends_count': 352, 'listed_count': 0, 'created_at': 'Fri Aug 30 16:37:32 +0000 2019', 'favourites_count': 378, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 10, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1181677842196832256/RpBBAsWU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1181677842196832256/RpBBAsWU_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1167476384522002432/1570568928', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': False, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1167476384522002432, id_str='1167476384522002432', name='badriya', screen_name='badriyanas', location='', description='عمل عمل عمل شغل عمل عمل موسيقى عمل فن عمل عمل عمل', url=None, entities={'description': {'urls': []}}, protected=True, followers_count=13, friends_count=352, listed_count=0, created_at=datetime.datetime(2019, 8, 30, 16, 37, 32), favourites_count=378, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=10, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1181677842196832256/RpBBAsWU_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1181677842196832256/RpBBAsWU_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/1167476384522002432/1570568928', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=True, default_profile_image=False, can_media_tag=False, followed_by=True, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none'),
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 2383721734, 'id_str': '2383721734', 'name': 'nawaf khalid', 'screen_name': 'rma_nawaf', 'location': 'Hala Madrid ', 'description': 'أذا مريت من هنا أستتغفر ❤️', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 134, 'friends_count': 469, 'listed_count': 0, 'created_at': 'Tue Mar 04 23:18:35 +0000 2014', 'favourites_count': 735, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1138, 'lang': None, 'status': {'created_at': 'Thu Nov 28 17:00:17 +0000 2019', 'id': 1200097087607717889, 'id_str': '1200097087607717889', 'text': '@BafGomis @Alhilal_FC I hope you are better now after the surgery ,actually what you sow that’s Alhilal the biggest… https://t.co/bjFP8agsPE', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BafGomis', 'name': 'Bafétimbi Gomis', 'id': 399681579, 'id_str': '399681579', 'indices': [0, 9]}, {'screen_name': 'Alhilal_FC', 'name': 'نادي الهلال السعودي', 'id': 28631535, 'id_str': '28631535', 'indices': [10, 21]}], 'urls': [{'url': 'https://t.co/bjFP8agsPE', 'expanded_url': 'https://twitter.com/i/web/status/1200097087607717889', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1200011895849340928, 'in_reply_to_status_id_str': '1200011895849340928', 'in_reply_to_user_id': 399681579, 'in_reply_to_user_id_str': '399681579', 'in_reply_to_screen_name': 'BafGomis', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1000938520024961024/Dy5BDnFG_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000938520024961024/Dy5BDnFG_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2383721734/1505932277', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=2383721734, id_str='2383721734', name='nawaf khalid', screen_name='rma_nawaf', location='Hala Madrid ', description='أذا مريت من هنا أستتغفر ❤️', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=134, friends_count=469, listed_count=0, created_at=datetime.datetime(2014, 3, 4, 23, 18, 35), favourites_count=735, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=1138, lang=None, status=Status(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'created_at': 'Thu Nov 28 17:00:17 +0000 2019', 'id': 1200097087607717889, 'id_str': '1200097087607717889', 'text': '@BafGomis @Alhilal_FC I hope you are better now after the surgery ,actually what you sow that’s Alhilal the biggest… https://t.co/bjFP8agsPE', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BafGomis', 'name': 'Bafétimbi Gomis', 'id': 399681579, 'id_str': '399681579', 'indices': [0, 9]}, {'screen_name': 'Alhilal_FC', 'name' ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 1200335228457377792, 'id_str': '1200335228457377792', 'name': 'Ashwaq', 'screen_name': 'AshwaqSlearning', 'location': 'Digital world', 'description': "Devoted  this account to share what I'm learning..", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3, 'friends_count': 36, 'listed_count': 0, 'created_at': 'Fri Nov 29 08:46:41 +0000 2019', 'favourites_count': 12, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 21, 'lang': None, 'status': {'created_at': 'Thu Dec 12 14:57:45 +0000 2019', 'id': 1205139681739988992, 'id_str': '1205139681739988992', 'text': 'Never ever stop trying... https://t.co/z6wibTOOYX', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1205139675096190978, 'id_str': '1205139675096190978', 'indices': [26, 49], 'media_url': 'http://pbs.twimg.com/media/ELmEJj7WkAIy2T3.jpg', 'media_url_https': 'https://pbs.twimg.com/media/ELmEJj7WkAIy2T3.jpg', 'url': 'https://t.co/z6wibTOOYX', 'display_url': 'pic.twitter.com/z6wibTOOYX', 'expanded_url': 'https://twitter.com/AshwaqSlearning/status/1205139681739988992/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1124, 'h': 582, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 352, 'resize': 'fit'}, 'large': {'w': 1124, 'h': 582, 'resize': 'fit'}}, 'features': {'medium': {'faces': []}, 'orig': {'faces': []}, 'small': {'faces': []}, 'large': {'faces': []}}}]}, 'extended_entities': {'media': [{'id': 1205139675096190978, 'id_str': '1205139675096190978', 'indices': [26, 49], 'media_url': 'http://pbs.twimg.com/media/ELmEJj7WkAIy2T3.jpg', 'media_url_https': 'https://pbs.twimg.com/media/ELmEJj7WkAIy2T3.jpg', 'url': 'https://t.co/z6wibTOOYX', 'display_url': 'pic.twitter.com/z6wibTOOYX', 'expanded_url': 'https://twitter.com/AshwaqSlearning/status/1205139681739988992/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1124, 'h': 582, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 352, 'resize': 'fit'}, 'large': {'w': 1124, 'h': 582, 'resize': 'fit'}}, 'features': {'medium': {'faces': []}, 'orig': {'faces': []}, 'small': {'faces': []}, 'large': {'faces': []}}}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1202098771645124608/ch-WUm4W_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1202098771645124608/ch-WUm4W_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1200335228457377792, id_str='1200335228457377792', name='Ashwaq', screen_name='AshwaqSlearning', location='Digital world', description="Devoted  this account to share what I'm learning..", url=None, entities={'d ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 2554560109, 'id_str': '2554560109', 'name': 'R8', 'screen_name': 'r881_', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 184, 'friends_count': 110, 'listed_count': 0, 'created_at': 'Sun Jun 08 11:45:01 +0000 2014', 'favourites_count': 166, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 107, 'lang': None, 'status': {'created_at': 'Wed Jul 10 17:42:16 +0000 2019', 'id': 1149010967747092487, 'id_str': '1149010967747092487', 'text': 'قد اوجد الاسلام حقوق الانسان الاجتماعية وقد اشاد بها ذلك المفهوم يعكس مدى لُحمة وترابط اي مجتمع وعدمه يعني مجتمع يس… https://t.co/MISjU4Tu67', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/MISjU4Tu67', 'expanded_url': 'https://twitter.com/i/web/status/1149010967747092487', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1086674654000021505/K3yeNOXO_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086674654000021505/K3yeNOXO_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=2554560109, id_str='2554560109', name='R8', screen_name='r881_', location='', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=184, friends_count=110, listed_count=0, created_at=datetime.datetime(2014, 6, 8, 11, 45, 1), favourites_count=166, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=107, lang=None, status=Status(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'created_at': 'Wed Jul 10 17:42:16 +0000 2019', 'id': 1149010967747092487, 'id_str': '1149010967747092487', 'text': 'قد اوجد الاسلام حقوق الانسان الاجتماعية وقد اشاد بها ذلك المفهوم يعكس مدى لُحمة وترابط اي مجتمع وعدمه يعني مجتمع يس… https://t.co/MISjU4Tu67', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/MISjU4Tu67', 'expanded_url': 'https://twitter.com/i/web/status/1149010967747092487', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, created_at=datetime.datetime(2019,  ...
# ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 3537185172, 'id_str': '3537185172', 'name': "-! ﴿' ﺑﻧنء ﻋﺑداﻟلہء", 'screen_name': 'binabdullah78', 'location': 'Muscat, Oman', 'description': '#alain #acmilan', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 164, 'friends_count': 332, 'listed_count': 0, 'created_at': 'Sat Sep 12 11:11:56 +0000 2015', 'favourites_count': 663, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 322, 'lang': None, 'status': {'created_at': 'Thu Dec 12 21:27:53 +0000 2019', 'id': 1205237864226795544, 'id_str': '1205237864226795544', 'text': '@391F ع الدايركت', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': '391F', 'name': 'TA Hacker', 'id': 1045836542, 'id_str': '1045836542', 'indices': [0, 5]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1205237771339739155, 'in_reply_to_status_id_str': '1205237771339739155', 'in_reply_to_user_id': 1045836542, 'in_reply_to_user_id_str': '1045836542', 'in_reply_to_screen_name': '391F', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1064221055085096960/NgrOElKj_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1064221055085096960/NgrOElKj_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3537185172/1542565047', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=3537185172, id_str='3537185172', name="-! ﴿' ﺑﻧنء ﻋﺑداﻟلہء", screen_name='binabdullah78', location='Muscat, Oman', description='#alain #acmilan', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=164, friends_count=332, listed_count=0, created_at=datetime.datetime(2015, 9, 12, 11, 11, 56), favourites_count=663, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=322, lang=None, status=Status(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'created_at': 'Thu Dec 12 21:27:53 +0000 2019', 'id': 1205237864226795544, 'id_str': '1205237864226795544', 'text': '@391F ع الدايركت', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': '391F', 'name': 'TA Hacker', 'id': 1045836542, 'id_str': '1045836542', 'indices': [0, 5]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1205237771339739155, 'in_reply_to_status_id_str': '1205237771339739155', 'in_reply_to_user_id': 1045836542, 'in_reply_to_user_id_str': '1045836542', 'in_reply_to_screen_name': '391F', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, created_at=datetime.datetime(2019, 12, 12, 21, 27, 53), id=1205237864226795544, id_str='1205237864226795544', tex ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 1022922114783952897, 'id_str': '1022922114783952897', 'name': 'λ', 'screen_name': '0x1337r00t', 'location': 'cache memory', 'description': '19 y/o ,Security Researcher and Software Engineer, noob, (تغريداتي ليست دائما مفيدة, سوف أتحدث عن النوتيلا), My tweets are my own / Parkour player .', 'url': 'https://t.co/vOTiI2nEIM', 'entities': {'url': {'urls': [{'url': 'https://t.co/vOTiI2nEIM', 'expanded_url': 'https://1337r00t.me', 'display_url': '1337r00t.me', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 9903, 'friends_count': 89, 'listed_count': 54, 'created_at': 'Fri Jul 27 19:10:11 +0000 2018', 'favourites_count': 889, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2339, 'lang': None, 'status': {'created_at': 'Thu Dec 12 20:35:31 +0000 2019', 'id': 1205224686164074497, 'id_str': '1205224686164074497', 'text': 'تمنيت ان عندي عندي وقت عشان اسويها لبقية اللغات البرمجية Go و Ruby و Java و Python و Rust و javascript ف اللي عندهم… https://t.co/1d0tQVHr2A', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/1d0tQVHr2A', 'expanded_url': 'https://twitter.com/i/web/status/1205224686164074497', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1205218831876186112, 'in_reply_to_status_id_str': '1205218831876186112', 'in_reply_to_user_id': 1022922114783952897, 'in_reply_to_user_id_str': '1022922114783952897', 'in_reply_to_screen_name': '0x1337r00t', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'ar'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1201683083738730498/oP2Na7oE_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1201683083738730498/oP2Na7oE_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1022922114783952897/1563923610', 'profile_link_color': '981CEB', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'can_media_tag': False, 'followed_by': True, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1022922114783952897, id_str='1022922114783952897', name='λ', screen_name='0x1337r00t', location='cache memory', description='19 y/o ,Security Researcher and Software Engineer, noob, (تغريداتي ليست دائما مفيدة, سوف أتحدث عن النوتيلا), My tweets are my own / Parkour player .', url='https://t.co/vOTiI2nEIM', entities={'url': {'urls': [{'url': 'https://t.co/vOTiI2nEIM', 'expanded_url': 'https://1337r00t.me', 'display_url': '1337r00t.me', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=9903, friends_count=89, listed_count=54, created_at=datetime.datetime(2018, 7, 27, 19, 10, 11), favourites_count=889, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=2339, lang=None, status=Status(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'created_at': 'Thu Dec 12 20:35:31 +0000 2019', 'id': 1205224686164074497, 'id_str': '1205224686164074497', 'text': 'تمنيت ان عن ...
#  User(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'id': 567566916, 'id_str': '567566916', 'name': 'Nahla Abd ALghany', 'screen_name': 'NahlaThabet', 'location': 'مصر', 'description': 'computer Engineer |organizer at @GDGDamanhour', 'url': 'https://t.co/khFB3wFXMU', 'entities': {'url': {'urls': [{'url': 'https://t.co/khFB3wFXMU', 'expanded_url': 'https://www.facebook.com/nahlathabet34', 'display_url': 'facebook.com/nahlathabet34', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 112, 'friends_count': 227, 'listed_count': 0, 'created_at': 'Mon Apr 30 19:31:08 +0000 2012', 'favourites_count': 798, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1069, 'lang': None, 'status': {'created_at': 'Tue Dec 10 16:24:35 +0000 2019', 'id': 1204436760014606338, 'id_str': '1204436760014606338', 'text': 'On page 140 of 256 of ملذات طوكيو, by Durian Sukegawa https://t.co/Bwbe9FXgr8', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Bwbe9FXgr8', 'expanded_url': 'https://goodreads.com/user_status/show/253835973', 'display_url': 'goodreads.com/user_status/sh…', 'indices': [54, 77]}]}, 'source': '<a href="http://www.goodreads.com" rel="nofollow">Goodreads</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'und'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'EDECE9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1194413899044528129/SSxUPG8O_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1194413899044528129/SSxUPG8O_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/567566916/1558033768', 'profile_link_color': '19CF86', 'profile_sidebar_border_color': 'D3D2CF', 'profile_sidebar_fill_color': 'E3E2DE', 'profile_text_color': '634047', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=567566916, id_str='567566916', name='Nahla Abd ALghany', screen_name='NahlaThabet', location='مصر', description='computer Engineer |organizer at @GDGDamanhour', url='https://t.co/khFB3wFXMU', entities={'url': {'urls': [{'url': 'https://t.co/khFB3wFXMU', 'expanded_url': 'https://www.facebook.com/nahlathabet34', 'display_url': 'facebook.com/nahlathabet34', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=112, friends_count=227, listed_count=0, created_at=datetime.datetime(2012, 4, 30, 19, 31, 8), favourites_count=798, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=1069, lang=None, status=Status(_api=<tweepy.api.API object at 0x7f01bfc54ac8>, _json={'created_at': 'Tue Dec 10 16:24:35 +0000 2019', 'id': 1204436760014606338, 'id_str': '1204436760014606338', 'text': 'On page 140 of 256 of ملذات طوكيو, by Durian Sukegawa https://t.co/Bwbe9FXgr8', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Bwbe9FXgr8', 'expanded_url': 'https://goodreads.com/user_status/show/253835973', 'display_url': 'goodreads.com/user_stat ...

# %%
type(test)
# Out:
# tweepy.models.User

# %% [markdown]
# # Analyzing tweets

# %% [markdown]
# ## Load saved data from Google Drive

# %%
# Load all saved tweets from @yakhoja
tweets = pd.read_csv(path + 'yakhoja_tweets.csv')

# %% [markdown]
# ### Classify tweets

# %%
# Classify the type of each tweet (i.e. Tweet, Reply, or Retweet)

tweets.retweeted = tweets.text.apply(lambda x: True if 'RT @' in x else False)
tweets['in reply to'] = tweets['in reply to'].fillna('N/A')
tweets['type'] = tweets['in reply to'].apply(lambda x: 'Tweet' if x == "yakhoja" or x == 'N/A' else 'Reply')
tweets.loc[tweets.retweeted, 'type'] = 'Retweet'
tweets.to_csv(path + 'yakhoja_tweets.csv')

# %%
# Find the number of tweets in each type
print('Total number of tweets = {}'.format(len(tweets)))
print('\nNumber of tweets by')
tweets.groupby('type').count().id
# Out:
# Total number of tweets = 1597
#
# Number of tweets by
# type
# Reply      748
# Retweet    237
# Tweet      612
# Name: id, dtype: int64

# %%
# Find the average number of likes per tweet type
tweets.groupby('type').mean().likes
# Out:
# type
# Reply       1.847594
# Retweet     0.000000
# Tweet      52.892157
# Name: likes, dtype: float64

# %%
# Find and print the top 10 tweets by number of likes
top10 = tweets.sort_values('likes',ascending=False)
top10 = top10.reset_index(drop=True)
top10 = top10.head(10)

for i in range(len(top10)):
  print("{}) At {} likes:".format(i+1, top10.likes[i]))
  print(top10.text[i]+"\n")
# Out:
# 1) At 2093 likes:
# الحمدلله أمس استعملت #الذكاء_الاصطناعي في حل مشكلة شخصية مزمنة كانت عندي....
#
# ... الا وهي اني ما اعرف افرق بين البق… https://t.co/4nUf6kaWQN
#
# 2) At 1584 likes:
# بعض الأمور التي ساعدتني على تنظيم وقتي ومهامي بالعمل
#
# - وضع أهداف للاسبوع
# - استعمال تطبيقات لقائمة المهام مثل Trell… https://t.co/ovbt1WnhGR
#
# 3) At 1254 likes:
# للمهتمين في #تعلم_الآلة ، هذا كتاب من ١٠٠ صفحة فقط يلخص اهم المبادئ الاحصائية و الرياضية و البرمجية مع امثلة و تدري… https://t.co/mglDeysNjB
#
# 4) At 1195 likes:
# في هذه السلسلة سأوضح كيف تبدأ في مجال تعلم الآلة من خلال منهجية تعالج أكبر 3 صعوبات قد تواجه المتعلم الذاتي حسب نتا… https://t.co/tnTrwpUw52
#
# 5) At 1144 likes:
# إذا شعرت بالتوتر لأن لديك عدد كبير من المهام ولا تدري أين تبدأ، فأتبع هذه الثلاث خطوات البسيطة
#
# ١) عدّد جميع المهام… https://t.co/Rc1TrVrVx2
#
# 6) At 1081 likes:
# مقال اكثر من رائع يحلل عودة مايكروسوفت للقمة منذ أن تولى ساتيا ناديلا قيادة الشركة في ٢٠١٤
#
# خلال ٢٠١٨ تجاوزت قيمة م… https://t.co/POd5Ouyfcz
#
# 7) At 1076 likes:
# أطلقت شركة #أمازون مجموعة مواد تدريبية مجانية في موضوع تعلم الآلة (جزء من #الذكاء_الاصطناعي)
#
# تنقسم المواد إلى 4 مس… https://t.co/1dzFSgu4u7
#
# 8) At 859 likes:
# من أجمل الدروس التي مرت علي خلال دراستي في ستانفورد هي قصة
#  Blue River Technology
#
# قد لا يكون الكثير قد سمع عن هذه… https://t.co/DV4j5ZpPTN
#
# 9) At 780 likes:
# شرائح من الاستاذ المشارك بكلية إدارة الاعمال بهارفارد @ThalesHBS بعنوان
#
# "كيف تحصل على أول ١٠٠٠ زبون - دروس من Uber… https://t.co/MNLt9xnAIM
#
# 10) At 692 likes:
# صورة لقرص صلب من IBM في ١٩٥٦ سعة تخزينه ٥ ميجابايت فقط!
#
# و اليوم نجد كرت ذاكرة بحجم ظفر الإصبع بسعة ٥١٢ جيجابايت
#
# ي… https://t.co/GQNR8BKXjZ

# %%
# Find tweets with likes > 49 but < 100
# 49 = the average number of likes my tweets get
# 100 was arbitrarily chosen

tweets[((tweets.likes > 49) & (tweets.likes < 100))].sort_values('likes',ascending=False)
# Out:
#                        id           created_at  ... retweeted   type
# 985   1120465979723649026  2019-04-22 23:14:41  ...     False  Tweet
# 111   1192276908521787392  2019-11-07 03:05:41  ...     False  Tweet
# 103   1193436702032818177  2019-11-10 07:54:17  ...     False  Tweet
# 459   1172891741063544833  2019-09-14 15:15:57  ...     False  Tweet
# 98    1194125191665897472  2019-11-12 05:30:06  ...     False  Tweet
# 89    1194766231355609088  2019-11-13 23:57:21  ...     False  Tweet
# 538   1170698934081032192  2019-09-08 14:02:31  ...     False  Tweet
# 1120  1111377439656050688  2019-03-28 21:20:04  ...     False  Tweet
# 592   1164339423913267200  2019-08-22 00:52:05  ...     False  Tweet
# 83    1195374534079025152  2019-11-15 16:14:32  ...     False  Tweet
# 142   1191588647801364481  2019-11-05 05:30:46  ...     False  Tweet
# 1017  1116851015511187456  2019-04-12 23:50:06  ...     False  Tweet
# 239   1183446946075181058  2019-10-13 18:18:33  ...     False  Tweet
# 927   1124422626875592704  2019-05-03 21:16:59  ...     False  Tweet
# 910   1125502090418069505  2019-05-06 20:46:23  ...     False  Tweet
# 439   1173920336611594242  2019-09-17 11:23:13  ...     False  Tweet
# 1438  1060050474085187584  2018-11-07 06:05:02  ...     False  Tweet
# 151   1191241377444696064  2019-11-04 06:30:51  ...     False  Tweet
# 979   1120465986006679553  2019-04-22 23:14:42  ...     False  Tweet
# 803   1130240779924852736  2019-05-19 22:36:15  ...     False  Tweet
# 85    1195212334211518465  2019-11-15 05:30:01  ...     False  Tweet
# 566   1169124307945099269  2019-09-04 05:45:30  ...     False  Tweet
# 310   1180546122571370496  2019-10-05 18:11:43  ...     False  Tweet
# 602   1163903884932206593  2019-08-20 20:01:25  ...     False  Tweet
# 622   1140984413188001798  2019-06-18 14:07:37  ...     False  Tweet
# 1353  1082761793657683968  2019-01-08 22:11:43  ...     False  Tweet
# 1189  1104355554535718918  2019-03-09 12:17:36  ...     False  Tweet
# 431   1174444278283526144  2019-09-18 22:05:10  ...     False  Tweet
# 687   1137247430305443840  2019-06-08 06:38:11  ...     False  Tweet
# 1016  1116873946643591169  2019-04-13 01:21:14  ...     False  Reply
# 785   1133804547137081344  2019-05-29 18:37:23  ...     False  Tweet
# 394   1177220135976722432  2019-09-26 13:55:26  ...     False  Tweet
# 361   1178775319647383557  2019-09-30 20:55:11  ...     False  Tweet
# 984   1120465980617056258  2019-04-22 23:14:41  ...     False  Tweet
# 1442  1060050468150231041  2018-11-07 06:05:01  ...     False  Tweet
# 769   1133833610212007936  2019-05-29 20:32:52  ...     False  Reply
# 588   1166000920141844481  2019-08-26 14:54:17  ...     False  Tweet
# 806   1129997707936878592  2019-05-19 06:30:22  ...     False  Tweet
# 472   1171944130051657729  2019-09-12 00:30:28  ...     False  Tweet
# 379   1177868823254331392  2019-09-28 08:53:05  ...     False  Tweet
# 1108  1111506268202500096  2019-03-29 05:51:59  ...     False  Tweet
# 537   1170698943920951296  2019-09-08 14:02:33  ...     False  Tweet
# 215   1186892077587554304  2019-10-23 06:28:17  ...     False  Tweet
# 533   1170698953936867334  2019-09-08 14:02:35  ...     False  Tweet
# 88    1194849963290873856  2019-11-14 05:30:05  ...     False  Tweet
# 954   1121490816227139584  2019-04-25 19:07:01  ...     False  Tweet
# 298   1181496538578571264  2019-10-08 09:08:20  ...     False  Tweet
# 1159  1106159005439680512  2019-03-14 11:43:52  ...     False  Tweet
# 109   1192675620746072064  2019-11-08 05:30:01  ...     False  Tweet
# 548   1170036775344955392  2019-09-06 18:11:20  ...     False  Tweet
#
# [50 rows x 7 columns]

# %%
plot_data = tweets[tweets.type == "Tweet"]
plot_data = plot_data[['id','created_at','likes']]
plot_data['time'] = plot_data['created_at'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,6))
fig.suptitle('Tweets vs. Likes Received')
ax1.scatter(plot_data.time, plot_data.likes)
ax2.scatter(plot_data.time, plot_data.likes)
left = date(2018, 10, 1)
right = date(2020, 1, 1)
ax2.set_xlim(left=left, right=right);
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #Analyzing followers

# %% [markdown]
# ##Load Saved data from Google Drive

# %%
followers = pd.read_json(path + 'followers_data.json') # Followers User ojbects

# %%
df = followers

df = df.fillna('Empty')

df = df.replace('','Empty')

# %%
# Create list of tags to identify each location
saudi_tags = ['saudi', 'ksa', 'riyadh', 'jeddah', 'makkah', 'madina', 'dammam', 'khobar', 'السعودية', 'السعوديه', 'جدة', 'الرياض', 'الدمام', 'neom', 'eastern', 'riyad', 'riydah', 'med', 'jed',
              'jubail', 'المدينة', 'ابها', 'مكة', 'sa', 'k.s.a', 'qatif', 'medina', 'tabuk', 'dhahran', 'abha', 'hail', 'qassim', 'mecca', 'ruh', 'buraydah', 'الخبر', 'الشرقية', 'الحجاز', 'بريدة', 'القصيم', 'المملكة العربية', 'جده', 'مكه',
              'الحد_الجنوبي', 'الحرمين', 'نجد', 'الرّس', 'j town', 'جازان', 'unayzah', 'الخُبر', 'الظهران', 'تبوك', 'حائل', 'طيبة', 'المجمعة', 'yanbu', 'taif', 'baljurashi', 'الأحساء', 'jeedah', '966', 'suudi', 'أملج', 'اللهم احفظ بلادي', 'الجبيل',
              'سعودية', 'ينبع', 'ryiadh', 'الطائف', 'jdh', 'Alkharj', 'طويق', 'الباحة', 'أم الملح', 'Al Badai', 'البدائع', 'الدرعيه', 'к.ѕ.α', 'المنوره', 'Abu Arish', 'Alkhober', 'rio', '🇸🇦', 'ام الملح', 'فوق هام السحب']

gulf_tags = ['uae', 'kuwait', 'qatar', 'yemen', 'oman', 'bahrain', 'اليمن', 'الإمارات', 'الكويت', 'قطر', 'البحرين', 'عمان', 'abu dhabi', 'q8', 'الجزيره',
             'dubai', 'الامارات', 'مسقط', 'شبه الجزيرة', 'جزيرة العرب', 'al ain', 'kwt', 'u.a.e', 'حضرموت', 'alain', 'arabian island']

mena_tags = ['egypt', 'مصر', 'libya', 'ليبيا', 'iraq', 'العراق', 'sudan', 'syria', 'jordan', 'الأردن', 'morocco', 'tunisia',
             'algeria', 'mauritania', 'palestine', 'فلسطين', 'cairo', 'gaza', 'الوطن العربي', 'Algiers', 'Marrakech', 'Mansoura', 'Algérie', 'amman', 'rafah', 'الاردن', 'لبنان', 'غزة', 'egy', 'eg', 'سوريا', 'حلب', 'الجزائر',
             'khartoum', 'tunis', 'الإسكندرية', 'السودان', 'lebanon', 'irbid', 'Touggourt', 'ramallah', 'سطيف', 'عمّـان', 'الأسكندرية', 'العالم الإسلامي', 'بلد المليون شهيد', 'MENA']

us_tags = ['us', 'united', 'states', 'usa', 'أمريكا', 'los angeles', 'NY', 'IL', 'DC', 'boston', 'stanford', 'philadelphia', 'CT', 'new orleans', 'miami', 'u.s.a', 'omaha',
           'new york', 'manhattan', 'mn', 'menlo park', 'wa', 'az', 'sf', 'tx', 'pa', 'or', 'portola valley', 'bay area', 'cambridge', 'va', 'fl', 'ga', 'lincoln', 'irvine', 'detroit', 'halifax',
           'ohio', 'nm', 'تكساس', 'co', 'oh', 'nc', 'الامريكية', 'cypress', '92108', 'West Lafayette', 'Utah']

uk_tags = ['uk', 'london', 'leeds', 'new castle', 'manchester', 'liverpool', 'england', 'ireland', 'scotland', 'glasgow']

euro_tags = ['paris', 'france', 'spain', 'munich', 'italy', 'netherlands', 'nederland', 'Deutschland', 'germany', 'berlin', 'finland', 'switzerland', 'sweden', 'stuttgart', 'Malmö', 'Sverige', 'Rotterdam']

canada_tags =['canada', 'british columbia', 'ontario', 'Montréal', 'calgary']

turkey_tags =['turkey', 'Türkiye']

# Create logical masks to clean up data
saudi = df.location.str.contains('|'.join(saudi_tags), case=False)
gulf = df.location.str.contains('|'.join(gulf_tags), case=False)
mena = df.location.str.contains('|'.join(mena_tags), case=False)
us = df.location.str.contains('|'.join(us_tags), case=False)
uk = df.location.str.contains('|'.join(uk_tags), case=False)
euro = df.location.str.contains('|'.join(euro_tags), case=False)
canada = df.location.str.contains('|'.join(canada_tags), case=False)
turkey = df.location.str.contains('|'.join(turkey_tags), case=False)
empty = df.location.str.contains('Empty')
other = saudi | gulf | mena | us | uk | euro | canada | turkey | empty
other = ~other

# Clean up data
df.loc[gulf, 'location'] = 'Gulf'
df.loc[mena, 'location'] = 'MENA'
df.loc[us, 'location'] = 'US'
df.loc[uk, 'location'] = 'UK'
df.loc[euro, 'location'] = 'Europe'
df.loc[canada, 'location'] = 'Canada'
df.loc[turkey, 'location'] = 'Turkey'
df.loc[saudi, 'location'] = 'Saudi Arabia'
df.loc[empty, 'location'] = 'Empty'
df.loc[other, 'location'] = 'Other'

print('Number of unique locations before clean up: ' + str(len(followers.location.unique())))
print('Number of unique locations after clean up: ' + str(len(df.location.unique())))
# Out:
# Number of unique locations before clean up: 2281
# Number of unique locations after clean up: 10

# %%
print('Total number of followers: {}\n'.format(len(followers)))

print('Followers by')
df.groupby('location').count().sort_values('id',ascending=False).id
# Out:
# Total number of followers: 9927
#
# Followers by
# location
# Empty           4446
# Saudi Arabia    3654
# US               617
# Other            609
# MENA             239
# Gulf             164
# UK               100
# Europe            56
# Canada            24
# Turkey            18
# Name: id, dtype: int64

# %%
# List the unique locations under Other

ids = df[df.location == 'Other'].id
followers[followers.id.isin(ids)].location.unique()
# Out:
# array(['     ', 'Algerie', "The sky's our limits", 'The Sky', 'Ey',
#        'الشارقة', 'Atlanta', 'Sky', 'unbounded ', 'Web',
#        'Tanger - Tétouan, Royaume du M', 'Ras Tannurah',
#        'التواصل والأسعـــــار والنماذج والتفاصيل في وتساب فقط 00971505673307',
#        'Snapchat: rbdis', '( إلى ربك يومئذ المستقر ) ',
#        'بين صفحات العروض ..', 'ارض الريتويت', 'Kosovo', 'Kalba',
#        '(Transit in الدنيا)', 'EVERYWhere', ' Planet Earth',
#        'ولكم في الأرض مستقر', 'الاحق رزقي', 'KAU',
#        'هدفي في الحياة رضا الله اولا ', '.', '127.0.0.1',
#        'كوكب الأرض حالياً', '♫', '  ', 'Home', 'Riydh',
#        'in middle of nowhere', 'يارب رُدني إليك رداً جميلا', '🎼',
#        'واق الواق', 'Somewhere on planet EARTH.', '“قدر قيمة الحياة.”',
#        'My Room ', 'earth', 'Microsoft', 'في غمرة العابرين!', '210 | 512',
#        'Earth ', 'over there', 'Online💡', 'Think Different',
#        'Here, There and Everywhere', 'Honolulu, HI', 'Neverland',
#        'من #زمن_الطيبين ', 'في ربوع وطني', '\U0001f9e0',
#        ' " لا أبرحُ حتى أبلغَ "', '24.580291,46.674957', 'no where',
#        'Somewhere ', 'GYM', 'استغفر الله وأتوب إليه ..', 'Homeland',
#        'رنيه الفيحاء ', 'Earth', 'أبها وخميس مشيط ',
#        'حيثُ يوجد السلام..!', 'Chicago ', '#العاصمة_المقدسة_بجوار_الحرم',
#        '👨🏻\u200d💻', 'choose love ', 'ـ', 'الجيزة', 'أرض الله الواسعة ',
#        'Loop, Chicago', '12/12/1995', 'جُدة', 'بقلب امي ❤️', 'زمرد ',
#        'Yharnam', '#Libra♎️. ', 'كلومبو', 'سيناء', 'الصراط المستقيم',
#        'NOWHERE', 'هنا ', 'Mumbai, India ', 'استغفرالله.', 'زحل', 'ضايع',
#        'Green Land', 'Montreal', ' ', 'الأرض',
#        "N 15°22' 0'' / E 44°10' 0''", 'الشارقة ', 'YE-Hadhrmut-Syoun',
#        'la la land ', 'المملكة المغربية', 'Royaume du Maroc🇲🇦', 'بهلا ',
#        'الخرمه', 'في أرض الله الواسعة ', 'ما دامت الحياة يبقى الأمل ',
#        'الاحساء', 'على قيد الحُلم والشغف ', 'مدينه رياض', 'تحت التدريب',
#        'حيثما أسجد لله', 'العاصمة', 'Dallas, Texas', 'Internet', 'Here',
#        'central perk', 'سُرادِق العَقل', 'Now I’m There', 'خليجي 🇰🇼',
#        'GCC', 'PS', 'Kl Malaysia', 'Somewhere in this planet',
#        'Home is where the heart is ❤', 'Rooftop',
#        'S A U D I   A R A B I A', 'بلادي اللي في قلبي', 'Global Citizen🌏',
#        '❤', 'كل الدنيا', 'In CS', 'Kuala Lumpur', 'هل ترانا؟ هل نراك؟',
#        'MARS 🌕', 'بالطريق إلى حلم آخر', 'Taibah', 'The Globe', 'yamen',
#        'شرق البلاد الوسيعة ', 'Tallinn, Estonia', 'الحياة الدنيا',
#        'في كنف الله💕', 'Noida, India', 'Indianapolis, IN', 'دار الخير',
#        'الخُبَر', 'TBA', 'فوق الأرض مؤقتا ', '🏢🏭', 'Empire, CA', '   ',
#        'Universe', 'أضرب ف الأرض ابتغي من فضل الله', 'Arabia',
#        'مونتريال - كندا', 'No where', 'la la land',
#        'Kuala Lumpur City, Kuala Lumpu', '#CGU',
#        'استغفر الله العظيم وأتوب إليه ', 'not the planet earth', 'Al Ula',
#        'Unknown', 'في قطار لا يتوقفْ', 'ربِ هب لي من تخيلاتي واقعاً *̠',
#        'وأمرهم شورى بينهم ', 'قِف على ناصية الحُلم و قاتِل!', '.....',
#        'Kyrgyzstan', 'بين حنين الماضي وحلم المستقبل ', 'iN Your Dreams',
#        'عدن', 'محمد الحربي...(هوايات متعددة)', 'Mars', 'In my place',
#        'في الفلك', 'Snapchat: D7oominho🎖', 'Loyola University Chicago',
#        'India', 'الشبكة العنكبوتية', 'اللهم آجعل همي ,الآخرة', 'Tubas',
#        'Brooklyn', 'Bleach', '🌌', 'نادي النصر طبعاً', 'Everywhere 🌍',
#        'بقلب أبي💛', 'ｙａｓｓｉｎｅ', 'EARTH ', 'على قدر حلمك... تتسع الأرض',
#        'Birmingham, AL', 'في قلب #العالمي', 'حول العالم', 'أم دودي',
#        'كوخ في عمق الغابة 🏚🌲', 'صمت', 'Everywhere ', 'snapchat : fahod4',
#        'ღ ججدّهـ ', 'Masdar City', 'قلب الصحراء،،', 'AD', 'Gotham ',
#        'Hamburg', 'بعيداً عن الزحام', 'Planet', 'هنا وهناك ', '❤️❤️',
#        'global', 'عرعر', 'وسط المعمعة', 'الرستاق', 'mauritanie',
#        'كوكب الارض', 'السويد', 'قارا_ الجوف', 'الواقع الإفتراضي.',
#        ' فوق الارض مؤقتاً', 'جيزان ', 'بلاد الاسلام',
#        'فى الدنيا حتى يقضى الله امرا', 'هوفيه مثل{قلبگ بيآض}يآلريآض؟',
#        'Between dream and achievement', 'Banana Republic', 'تمبول',
#        'sdsScrns', 'في قلب سعوديتنآ ', 'زيورخ', 'ورى ظهر النهار', '🛰',
#        ' أفكارك لك لكن أقوالك لغيرك', 'بلاد العرب اوطاني', '💓',
#        'Earth Planet', 'Somalia', 'الحساب ليس للاستشارات..',
#        '                         ❸ⓣⓠ❶❸', ' جنب الشاحن ',
#        'طريق صلاح الدين الايوبي،الملز', 'Malaysia - KL', 'الخرطوم',
#        'Here, There & Everywhere', '512-Bit_C8991, R18', '127.0 .0.1',
#        'لا إله إلا الله', 'السويدي', 'في كبد', '🇦🇪🇵🇸',
#        'Najran - Najran University', '. ', 'suadiArabai', 'القنفذة',
#        'المريخ', 'C-137', 'Novigrad', '🇦🇪',
#        ' أحبكم الى الله انفعكم للناس', 'Planet Earth',
#        "I don't like being followed.", 'I live in the Internet',
#        'Not everywhere.', 'ربي احسن رحيلي إن حان وقته ', '_',
#        'بين السهول والرمال ', 'مدغشقر', 'Malaysia', 'خلفك ! - عنيزة',
#        '﴿لا أبرح حتى أبلغ﴾', 'مَكّةُ الْمُكَرّمَة',
#        'الارض وطني الاول والاخير', 'اعلى من الغيم إشراقاً.وبي أملٌ',
#        '16.972357,42.812169', 'العالم البائس', '¯\\_(ツ)_/¯',
#        'عميق الذاكرة.. زوايا الحلم!!', 'Everywhere', ' 🔛 ',
#        'techiebits.net', 'The peaceful land', 'at 127.0.0.1 😌🌚', '~/',
#        'Under Ground', 'Assuit', 'no where ', 'كوكب دري وهابي',
#        '21.4417,39.797652', 'Somewhere', 'دكتوراه علم البيئة والتلوث',
#        'ココ', 'المحيط ', 'لا يوجد ', 'استغفر الله ',
#        '🇵 ☕⚘🗺🎶🎙📸📚🤖 Digitalista ', '• iNstagram: @ishr0', 'خَلفَ البَابْ',
#        'لاجئ ف أي مكان فيه فيشه ونت 😂', 'Planet Earth 🌍🌌',
#        'Possibly the pub', 'في كوكب الارض', 'خضراء حجر', '٨',
#        'Castle Oblivion', 'Somewhere near the earth', 'not here', 'لبقآع',
#        'Quantum Field', 'dimension c-137', '\U0001f9e1', '\uf8ff',
#        'Happiness', 'أرض بلا شعب', ' ♥بعيداً حيث الانسانيه', 'Got',
#        'اللهّم اغفر لنا ذنوبنا', '~My own happy kingdom~',
#        'la vie est belle', 'She/Her', 'My Mind', 'Du', 'Mars ',
#        'Your MIND', 'On My Desktop', 'بيتنا', '♀\xa0Ⓥ ♪ ☮ ',
#        'Right here..', 'Kernel ', 'دلوية ', '💌', 'المكان المقابل',
#        '               ً.           ', 'في لطف الله وستره ✨', 'universe',
#        'Global', 'Jakarta Indonesia', '♏', 'Aden', 'الشرقي',
#        'كل بلدان المسلمين خاص والعالم ', 'Stage!',
#        'العالم هو مكاني الفسيح', 'Self deveopment | Books ', 'SomeWhere',
#        '24.457609,39.643119', 'NoWhere', 'في اعظم بقعة', 'الرامي أ*',
#        'انا حيث انا', 'أبعد زاوية من زوايا العالم', 'Thoughts',
#        'Global Citizen', 'بين هذا وذاك', 'around', 'الأرض المباركه.',
#        'Trento, Trentino-Alto Adige', 'Atlantis', 'بالأرض',
#        ' (إنّ لِي نفساً تَواقة)', 'In the earth ', '🌍', 'Laniakea',
#        'Snapchat:', '🌎 ', 'somewhere ', 'السماء السابعه..', '404',
#        'Brisbane, Queensland', '#NFC', 'ionia',
#        'Alger                         ', 'مقهى فاروق..*', 'Online',
#        'مر على قناتي تجد الكثير👇', 'لبعيد ..', 'نفس المكان', '🇴🇲🖤',
#        'دائماً فوق الغيوم', 'الاطلس ', 'بيت أبو ابراهيم ', 'Nearby', '🎗',
#        'sydney', 'اللهم اسعدنا بطاعتك', 'بالصالون', 'The globe',
#        'الإرتقاء المعرفي', 'Among The Stars!', 'In thd cloud', 'قلب امي ',
#        'مجرة درب التبّانة', '... ', 'Never Settled', 'حيث أمرع البلقع ',
#        '🌏 ', 'Hiro', 'في مكان ما على سطح الارض ', 'سوق العمل',
#        'خارج نطاق الراحة ', 'لا إله إلا الله ', 'اللهم آمنا في اوطاننا ',
#        'Snapchat: m7mdbederi', ' في قلب أحبابي',
#        'instagram, snapchat : mo7mmadx', 'Mars ♋️ ', 'Snap: LLOYEDS ',
#        'home', 'استغفر الله', 'Globe', 'حيثما تكون أكون ',
#        'Douala-Cameroon', 'المدونة', 'online', 'JD', 'أرض الرسالة',
#        'snap: a_alshetwi', 'المشاعر والأحاسيس ', 'أعيشُ بِـ مَنفى !',
#        'أبحث عن وطن ', 'كوكب الأرض', 'Shit Land', 'حساب ساخر',
#        '🔖Ambition.', 'ادعموا وسم #وقف', 'ÜT: 26.3922152,43.9587574',
#        'Västerås', 'Under Kármán line', 'ارض الله الواسعه', 'Peace',
#        'Earth 🌐 ', 'بين الأرض والسماء', 'Earth Dimension C-137', 'حيدان',
#        'ماوصف الجنة .. إلا و دمشق مثله', 'الشمال الشرقي', '/root/',
#        'Unspecified', 'عَرَبي ـ  بيتُ الحِكمة   ', 'Maadi',
#        '! على هذه البسيطة', 'Itay elbarod,El behera,',
#        '24.761787,46.705305', 'وتستمر الحياه ', 'في الاحلام',
#        'تحت ظل تلك الشجرة', '🌍 ~ 🌐', 'سفينة نوح ',
#        'Home Is Where The Heart Is 🏠', '🌍✈️⭐️✨', 'Ten Dimensions',
#        'My bed', '# لـنـرتـقـي الـوقـتُ يـمـضـي', 'هنا ، بالقرب منك . ',
#        '((واتقوا الله ويعلمكم الله))', 'WF', 'out of the earth',
#        'Kingdom of Jahra 🏹', 'الروح في بلد والجسد في بلد',
#        'Planet Earth 🌍 ', 'univers', 'غرفتي', 'alRaki ♚', 'On Earth',
#        'under the shining star', 'In The Middle of No Where.',
#        'Somewhere under the rainbow \ue20c', 'حيث السلام ', 'Oude pekela',
#        'الانسانية موطني', 'بعضي هنا والبعض الآخر هناك!', 'بحر الغدر',
#        'Linux OS', 'أعظم بلد 💚', 'pwd', 'Niger', 'ارض الله',
#        '25 September💛', 'Madison, WI', 'بلد التوحيد', 'أوروبا الجديدة',
#        '#رابطه_عشاق_العطور', 'TABADUL ', 'مدينة النخيل ', 'China, jinhua',
#        '@Jnrutr96 حسابي القديم', 'حيث توجد المعرفة', '\u200fE=mc²',
#        'Kuala Lumpur City', 'nouakchott', 'WWW', 'Somewhere in my head ',
#        'غربة وطن', 'Univers', '🇰🇼 | MCR', 'The Drunken Clam', 'C.R.E.A.M',
#        'العالم', 'idk', 'مكاني أينما أكون ', 'الحمدلله', 'Dhofar',
#        'Buenos Aires', 'Clock Tower', 'Mars. ', 'بعيد شوي',
#        'حوران، مهد النخوة والكرم', 'Ibb', 'Current Address : Earth',
#        'بوابة المصادر المفتوحة', 'C', 'للحجز السريع للمواعيد الرابط :',
#        'here', 'بين شرق الجزيرة وغربها', 'مبادرة سناب مهارات البزنس',
#        'في دولة اسمها .. أمي ❤️', '1 AU', 'على وجهه هذه البسيطه',
#        'Ethiopia', '-في بيتنا-',
#        'وَأَنْ لَيْسَ لِلْإِنْسَانِ إِلَّا مَا سَعَى', 'On the Earth ',
#        'Cloud ☁️', 'Epoch 5', 'onEarth($event) ', 'مدينة المخفية في العج',
#        'Area 51 تاني نجمة عاليمين', 'localhost', 'Multiverse',
#        'Greater Accra, Ghana', 'here and there ..',
#        'استغفر الله العظيم من كل ذنوبي', 'On The internet', 'LHR ↔ KWI',
#        'Here & there', ': Inside & Outside the Lab :',
#        'Robot Tweeting & Retweeting', ' الزعيم الاسيوي ♡ ~', 'all in one'],
#       dtype=object)

# %%
print("Number of followers who have more than 30k followers: {}".format(len(df.loc[df.followers_count >= 3e4])))
print('Number of verified followers: {}'.format(len(df[df.verified == True])))
# Out:
# Number of followers who have more than 30k followers: 58
# Number of verified followers: 31

# %% [markdown]
# #Analyzing following

# %% [markdown]
# ## Load Saved Data from Google Drive

# %%
following = pd.read_json(path + 'friends_data.json')       # Friends User ojbects

# %%
df = following

df = df.fillna('Empty')

df = df.replace('','Empty')

# %%
# Create list of tags to categorize following
saudi_gov_url_tags =['.gov.sa', 'neom', 'qiddiya', '.sa', '.com.sa']
saudi_gov_bio_tags = ['وزير', 'نائب مدير', 'وكيل', 'وزارة', 'محافظ', 'هيئة', 'مدير']
academic_url_tags =['.edu']
academic_bio_tags =['prof', 'professor', 'research', 'أستاذ']
vc_tags =  ['fund', 'vc', 'partner', 'investor', 'venture', 'gp']
ai_tags =  ['ai', 'ml', 'deep learning', 'machine learning', 'vision', 'keras', 'tensorflow', 'Data Scientist', 'Data Science', 'nlp', 'xgboost', 'علم البيانات']
product_tags =  ['product', 'cpo', 'design', 'PM']
fitness_tags = ['fitness', 'muscle', 'nba']
ceo_tags = ['ceo', 'الرئيس التنفيذي']
magazine_tags =  ['forbes', 'techcrunch', 'inc', 'nat geo', 'harvardbiz', 'engadget', 'freakonomics', 'tedtalks', 'reutersbiz', 'huffpost', 
                  'wsj', 'business', 'theeconomist', 'bw', 'businessinsider', 'cnn', 'time', 'popmech', 'Entrepreneur', 'fastcompany', 'alarabiya']
writer_tags =  ['writer', 'editor', 'author', 'journalist', 'skinny canadian', 'news', 'report', 'cover', 'كاتب', 'صحفي', 'أكتب', 'writing', 'correspondent']
energy_tags = ['energy', 'exxon', 'أرامكو']
startup_tags = ['founder', 'yc', 'ycw', 'co-founder', 'مؤسس']
programmer_tags = ['developer', 'software', 'linux', 'hacker', 'هاكر', 'مطور', 'مبرمج', '.net', 'php', 'laravel', 'gnu', 'engineer', 'cto']


# Create logical masks to clean up data

# Based on URL
saudi_gov_url = df['url'].str.contains('|'.join(saudi_gov_url_tags), case=False)
academic_url = df['url'].str.contains('|'.join(academic_url_tags), case=False)

# Based on twitter profile bio
saudi_gov_bio = df['description'].str.contains('|'.join(saudi_gov_bio_tags), case=False)
academic_bio = df['description'].str.contains('|'.join(academic_bio_tags), case=False)
vc = df['description'].str.contains('|'.join(vc_tags), case=False)
ai = df['description'].str.contains('|'.join(ai_tags), case=False)
product = df['description'].str.contains('|'.join(product_tags), case=False)
writer = df['description'].str.contains('|'.join(writer_tags), case=False)
fitness = df['description'].str.contains('|'.join(fitness_tags), case=False)
energy = df['description'].str.contains('|'.join(energy_tags), case=False)
startup = df['description'].str.contains('|'.join(startup_tags), case=False)
ceo = df['description'].str.contains('|'.join(ceo_tags), case=False)
programmer = df['description'].str.contains('|'.join(programmer_tags), case=False)

# Based on twitter ID
magazine = df['screen_name'].str.contains('|'.join(magazine_tags), case=False)

# Based on a combination 
saudi_gov = saudi_gov_url | saudi_gov_bio
academic = academic_url | academic_bio
media = writer | magazine

# Clean up data
df.loc[saudi_gov, 'Category'] = 'Saudi Gov'
df.loc[academic, 'Category'] = 'Academic'
df.loc[vc, 'Category'] = 'VC'
df.loc[ai, 'Category'] = 'AI'
df.loc[product, 'Category'] = 'Product'
df.loc[media, 'Category'] = 'Media (writer/magazine)'
df.loc[fitness, 'Category'] = 'Fitness'
df.loc[energy, 'Category'] = 'Energy'
df.loc[startup, 'Category'] = 'Startup'
df.loc[ceo, 'Category'] = 'CEO'
df.loc[programmer, 'Category'] = 'Programmer'
df.fillna('Other',inplace=True)

# %%
print('Total number of users I\'m following: {}\n'.format(len(following)))

print('Following by')
df.groupby('Category').count().id.sort_values(ascending=False)
# Out:
# Total number of users I'm following: 1470
#
# Following by
# Category
# Other                      399
# Programmer                 225
# AI                         168
# Media (writer/magazine)    162
# Startup                    124
# Product                     96
# CEO                         88
# VC                          70
# Saudi Gov                   55
# Energy                      36
# Academic                    33
# Fitness                     14
# Name: id, dtype: int64

# %%
# List the users under Other

ids = df[df.Category == 'Other'].id
following[following.id.isin(ids)][['screen_name','description']]
# Out:
#           screen_name                                        description
# 4        JeddahAmanah  الحساب الرسمي لـ #أمانة_جدة | للطوارئ والبلاغا...
# 7        makkahregion  حساب إخباري لـ #إمارة_مكة للتواصل: prjeddah@ma...
# 10             g20org  The Official Account of #G20SaudiArabia\nالحسا...
# 16            taqa_sa  الحملة الوطنية لترشيد استهلاك الطاقة #لتبقى.. ...
# 21         SaudiBanks  الحساب الرسمي للجنة الاعلام والتوعية المصرفية ...
# ...               ...                                                ...
# 1423        BillGates  Sharing things I'm learning through my foundat...
# 1429          HashKSA  الآن،، جوالنا المجاني حصريًا على STC أرسل 1 لل...
# 1430           spagov  الحساب الرسمي لـ واس الخاص بأخبار خادم الحرمين...
# 1431  JosephEStiglitz  The official account of Joseph E. Stiglitz, No...
# 1436          MargRev            Small steps toward a much better world.
#
# [399 rows x 2 columns]

# %%
# Unfollow all users in the fitness category

fitness_df = df[df.Category == 'Fitness']

for _, row in fitness_df.iterrows():    # iterate over rows in the fitness data
  api.destroy_friendship(row['id'])     # use twitter api to unfollow based on id

# %% [markdown]
# # Analyzing History

# %% [markdown]
# ## Load Saved Data from Google Drive

# %%
history = pd.read_json(path + 'follower_history.json').transpose()     # Follower history dictionary
dates = history.index.strftime('%b %d')

# %%
# Plot the number of my followers over time

plt.bar(dates, history.followers, figure=plt.figure(figsize=(10,6)), width=0.4);
plt.ylim(8000, 1e4);
plt.title('Followers over time in 2019');

# %%
# Plot number of users I'm following over time

plt.bar(dates, history.following, figure=plt.figure(figsize=(10,6)), width=0.4);
plt.ylim(1.35e3, 1.48e3);
plt.title('Following over time in 2019');
